# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('StudentsPerformance-modified1.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Scanning all inconsistencies
df.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     43
# reading score                   6
# writing score                   9
# dtype: int64

# %%
df=df.dropna(subset=['reading score'])#coloumn wise removal of NULL values.

# %%
df.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     43
# reading score                   0
# writing score                   9
# dtype: int64

# %%
df.shape
# Out:
# (994, 8)

# %%
df.dropna(axis=0)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.shape
# Out:
# (994, 8)

# %%
df.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     43
# reading score                   0
# writing score                   9
# dtype: int64

# %%
df['math score'].fillna(df['math score'].mean(), inplace=True)
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\4162807602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['math score'].fillna(df['math score'].mean(), inplace=True)

# %%
df['math score'].head(20)
# Out:
# 0     72.000000
# 1     69.000000
# 2     90.000000
# 3     47.000000
# 4     76.000000
# 5     71.000000
# 6     88.000000
# 7     40.000000
# 8     64.000000
# 9     38.000000
# 10    58.000000
# 11    40.000000
# 12    65.000000
# 13    78.000000
# 14    50.000000
# 15    69.000000
# 16    88.000000
# 17    66.301788
# 18    66.301788
# 19    66.301788
# Name: math score, dtype: float64

# %%
df['math score'].fillna(df['math score'].median(), inplace=True)
df['math score'].head(25)
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\2156175285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['math score'].fillna(df['math score'].median(), inplace=True)
# 0     72.000000
# 1     69.000000
# 2     90.000000
# 3     47.000000
# 4     76.000000
# 5     71.000000
# 6     88.000000
# 7     40.000000
# 8     64.000000
# 9     38.000000
# 10    58.000000
# 11    40.000000
# 12    65.000000
# 13    78.000000
# 14    50.000000
# 15    69.000000
# 16    88.000000
# 17    66.301788
# 18    66.301788
# 19    66.301788
# 20    66.301788
# 21    66.301788
# 22    66.301788
# 23    66.301788
# 24    74.000000
# Name: math score, dtype: float64

# %%
df['math score'].median()
# Out:
# 66.30178759200841

# %%
df['math score'].fillna(df['math score'].mode().iloc[0], inplace=True)
df['math score'].mode()
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\4103377633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['math score'].fillna(df['math score'].mode().iloc[0], inplace=True)
# 0    66.301788
# Name: math score, dtype: float64

# %%
df['math score'].head(25)
# Out:
# 0     72.000000
# 1     69.000000
# 2     90.000000
# 3     47.000000
# 4     76.000000
# 5     71.000000
# 6     88.000000
# 7     40.000000
# 8     64.000000
# 9     38.000000
# 10    58.000000
# 11    40.000000
# 12    65.000000
# 13    78.000000
# 14    50.000000
# 15    69.000000
# 16    88.000000
# 17    66.301788
# 18    66.301788
# 19    66.301788
# 20    66.301788
# 21    66.301788
# 22    66.301788
# 23    66.301788
# 24    74.000000
# Name: math score, dtype: float64

# %%
maxx=df['math score'].max()#min-max norm. method
minn=df['math score'].min()
dfn=[((x-minn)/(maxx-minn)) for x in df['math score']]
df['math_score_norm']=dfn
#df.head()
#df['math score'].plot(kind='box')
df['math_score_norm'].plot(kind='box')
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\1451632085.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['math_score_norm']=dfn
# <Axes: >

# %%
meann=df['reading score'].mean()#z-score method
stdd=df['reading score'].std()
dfz=[((x-meann)/stdd) for x in df['reading score']]
df['reading_score_z']=dfz;
df.head(10)
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\1471085217.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reading_score_z']=dfz;
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# ...

# %%
q1 = df.quantile(0.25)#IQR and box-plot method
q3 = df.quantile(0.75)

iqr=q3-q1
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\3155364757.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q1 = df.quantile(0.25)
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\3155364757.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q3 = df.quantile(0.75)

# %%
ll = q1-(1.5*iqr)#formulas
ul = q3+(1.5*iqr)

# %%
ll
# Out:
# math score         28.500000
# reading score      26.500000
# writing score      26.500000
# math_score_norm     0.277778
# math_score_z       -2.109852
# dtype: float64

# %%
ul
# Out:
# math score         104.500000
# reading score      110.500000
# writing score      110.500000
# math_score_norm      0.457447
# math_score_z         2.131978
# dtype: float64

# %%
low=df<ll
high=df>ul
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\3659648455.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   low=df<ll
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\3659648455.py:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   high=df>ul

# %%
high
# Out:
#      gender  lunch  math score  math_score_norm  math_score_z  \
# 0     False  False       False            False         False
# 1     False  False       False            False         False
# 2     False  False       False            False         False
# 3     False  False       False            False         False
# 4     False  False       False            False         False
# ..      ...    ...         ...              ...           ...
# 995   False  False       False            False         False
# 996   False  False       False            False         False
# 997   False  False       False            False         False
# 998   False  False       False            False         False
# 999   False  False       False            False         False
#
#      parental level of education  race/ethnicity  reading score  \
# 0                          False           False          False
# 1                          False           False          False
# ...

# %%
df[high | low]#Union of lower & higher values than ll and ul
# Out:
#     gender race/ethnicity parental level of education lunch  \
# 0      NaN            NaN                         NaN   NaN
# 1      NaN            NaN                         NaN   NaN
# 2      NaN            NaN                         NaN   NaN
# 3      NaN            NaN                         NaN   NaN
# 4      NaN            NaN                         NaN   NaN
# ..     ...            ...                         ...   ...
# 995    NaN            NaN                         NaN   NaN
# 996    NaN            NaN                         NaN   NaN
# 997    NaN            NaN                         NaN   NaN
# 998    NaN            NaN                         NaN   NaN
# 999    NaN            NaN                         NaN   NaN
#
#     test preparation course  math score  reading score  writing score  \
# 0                       NaN         NaN            NaN            NaN
# 1                       NaN         NaN            NaN            NaN
# ...

# %%
out=df[~(low | high).any(axis=1)]
out.plot(kind="box")
# Out:
# <Axes: >

# %%
out
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
out.describe()
# Out:
#        math score  reading score  writing score  math_score_norm  math_score_z
# count  954.000000     954.000000     954.000000       954.000000    954.000000
# mean    66.590005      69.498952      68.440347         0.367825      0.016086
# std     14.158864      14.123370      14.542176         0.033472      0.790257
# min     29.000000      28.000000      27.000000         0.278960     -2.081946
# 25%     58.000000      60.000000      58.000000         0.347518     -0.463352
# 50%     66.301788      70.000000      69.000000         0.367144      0.000000
# 75%     76.000000      79.750000      79.000000         0.390071      0.541292
# max    100.000000     100.000000     100.000000         0.446809      1.880817

# %%
out.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 954 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       954 non-null    object
#  1   race/ethnicity               954 non-null    object
#  2   parental level of education  954 non-null    object
#  3   lunch                        954 non-null    object
#  4   test preparation course      954 non-null    object
#  5   math score                   954 non-null    float64
#  6   reading score                954 non-null    float64
#  7   writing score                954 non-null    float64
#  8   math_score_norm              954 non-null    float64
#  9   math_score_z                 954 non-null    float64
# dtypes: float64(5), object(5)
# memory usage: 82.0+ KB

# %%
out.shape
# Out:
# (954, 10)

# %%
out
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df['math_score_norm'],df['reading_score_z'])
plt.xlabel('math_score_norm')
plt.ylabel('reading_score_z')
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
import numpy as np
df['writing score']=np.log(df['writing score'])
df.head(10)
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\2746161716.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['writing score']=np.log(df['writing score'])
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# ...

# %%
import seaborn as sns
sns.kdeplot(df['writing score'])
print("Skewness: ",df['writing score'].skew())
#plt.show()
# Out:
# Skewness:  0.10198825467865143

# %%
df['writing score']=np.sqrt(df['writing score'])
sns.kdeplot(df['writing score'])
print("Skewness: ",df['writing score'].skew())
# Out:
# Skewness:  -0.8628598960848258
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_24668\1713800200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['writing score']=np.sqrt(df['writing score'])

# %%
df['writing score']
# Out:
# 0      1.440356
# 1      1.454638
# 2      1.459106
# 3      1.394740
# 4      1.441477
#          ...
# 995    1.460815
# 996    1.414861
# 997    1.429382
# 998    1.443669
# 999    1.452767
# Name: writing score, Length: 994, dtype: float64

# %%
df.drop(['math_score_norm'],axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
###End
